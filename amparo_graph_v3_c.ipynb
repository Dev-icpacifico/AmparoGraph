# %%
# %%capture --no-stderr
# %pip install --quiet -U langchain_openai langchain_core langgraph langchain_community langchain_anthropic langchain_experimental faiss-cpu tiktoken pypdf langchain openai langchain_anthropic langchain_experimental
# Out:
# Requirement already satisfied: langchain in c:\users\luis pizarro\anaconda3\lib\site-packages (0.3.21)
# Requirement already satisfied: openai in c:\users\luis pizarro\anaconda3\lib\site-packages (1.68.2)
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.10.0-cp39-cp39-win_amd64.whl (13.7 MB)
#      ---------------------------------------- 13.7/13.7 MB 4.7 MB/s eta 0:00:00
# Requirement already satisfied: tiktoken in c:\users\luis pizarro\anaconda3\lib\site-packages (0.9.0)
# Requirement already satisfied: pypdf in c:\users\luis pizarro\anaconda3\lib\site-packages (5.4.0)
# Requirement already satisfied: requests<3,>=2 in c:\users\luis pizarro\anaconda3\lib\site-packages (from langchain) (2.28.1)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.7 in c:\users\luis pizarro\anaconda3\lib\site-packages (from langchain) (0.3.7)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.45 in c:\users\luis pizarro\anaconda3\lib\site-packages (from langchain) (0.3.48)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\luis pizarro\anaconda3\lib\site-packages (from langchain) (2.10.6)
# Requirement already satisfied: langsmith<0.4,>=0.1.17 in c:\users\luis pizarro\anaconda3\lib\site-packages (from langchain) (0.3.15)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\luis pizarro\anaconda3\lib\site-packages (from langchain) (1.4.39)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\luis pizarro\anaconda3\lib\site-packages (from langchain) (6.0)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in c:\users\luis pizarro\anaconda3\lib\site-packages (from langchain) (4.0.3)
# Requirement already satisfied: tqdm>4 in c:\users\luis pizarro\anaconda3\lib\site-packages (from openai) (4.67.1)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\luis pizarro\anaconda3\lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\luis pizarro\anaconda3\lib\site-packages (from openai) (0.9.0)
# Requirement already satisfied: typing-extensions<5,>=4.11 in c:\users\luis pizarro\anaconda3\lib\site-packages (from openai) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\luis pizarro\anaconda3\lib\site-packages (from openai) (0.28.1)
# Requirement already satisfied: sniffio in c:\users\luis pizarro\anaconda3\lib\site-packages (from openai) (1.2.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\luis pizarro\anaconda3\lib\site-packages (from openai) (4.9.0)
# Requirement already satisfied: packaging in c:\users\luis pizarro\anaconda3\lib\site-packages (from faiss-cpu) (24.2)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in c:\users\luis pizarro\anaconda3\lib\site-packages (from faiss-cpu) (2.0.2)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\luis pizarro\anaconda3\lib\site-packages (from tiktoken) (2022.7.9)
# Requirement already satisfied: idna>=2.8 in c:\users\luis pizarro\anaconda3\lib\site-packages (from anyio<5,>=3.5.0->openai) (3.3)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\luis pizarro\anaconda3\lib\site-packages (from anyio<5,>=3.5.0->openai) (1.2.2)
# Requirement already satisfied: httpcore==1.* in c:\users\luis pizarro\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.7)
# Requirement already satisfied: certifi in c:\users\luis pizarro\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->openai) (2022.9.14)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\luis pizarro\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\luis pizarro\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.45->langchain) (9.0.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\luis pizarro\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.45->langchain) (1.33)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\luis pizarro\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (3.10.15)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\luis pizarro\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (0.23.0)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\luis pizarro\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\luis pizarro\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\luis pizarro\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.27.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\luis pizarro\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (1.26.11)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\luis pizarro\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (2.0.4)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\luis pizarro\anaconda3\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (1.1.1)
# Requirement already satisfied: colorama in c:\users\luis pizarro\anaconda3\lib\site-packages (from tqdm>4->openai) (0.4.5)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\luis pizarro\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.45->langchain) (3.0.0)
# Installing collected packages: faiss-cpu
# Successfully installed faiss-cpu-1.10.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# Importación de librerias
# LangGraph
from langgraph.graph import START, END, StateGraph
from langgraph.types import Command
from langgraph.prebuilt import create_react_agent

# LangChain
from langchain_core.messages import HumanMessage
from langchain_openai import ChatOpenAI, OpenAIEmbeddings
from langchain_community.tools.tavily_search import TavilySearchResults
from langchain.tools.retriever import create_retriever_tool
from langchain.vectorstores import FAISS
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.document_loaders import PyPDFLoader
from langchain_core.prompts import ChatPromptTemplate
# Utilidades
from typing import TypedDict, Optional, Dict, List, Literal, Annotated
from dotenv import load_dotenv, find_dotenv
import tiktoken
from IPython.display import Image, display

# %%
# Carga de variables de entorno
dotenv_path = find_dotenv()
load_dotenv(dotenv_path)
# Out:
# True

# %%
def count_tokens_in_docs(docs, model_name="gpt-4o"):
    """
    Calcula la cantidad total de tokens para una lista de documentos
    usando la librería tiktoken.

    :param docs: Lista de documentos (por ejemplo, la salida de un loader PDF).
    :param model_name: Nombre del modelo para el que queremos simular el conteo.
    :return: Número total de tokens en el contenido de los documentos.
    """
    # Obtenemos la codificación que usa el modelo seleccionado
    encoding = tiktoken.encoding_for_model(model_name)

    total_tokens = 0
    for doc in docs:
        # doc.page_content es el texto de cada página/documento
        text = doc.page_content
        total_tokens += len(encoding.encode(text))

    return total_tokens

# %%
# 2. CARGA DEL PDF
# ----------------------------------------------------------------------------
file_path = "carga.pdf"
loader = PyPDFLoader(file_path)
docs = loader.load()

# %%
# Cantidad de documentos extraídos (páginas, secciones, etc. según PyPDFLoader)
print("Número de docs cargados:", len(docs))

# Opcional: vista previa de los primeros 100 caracteres de la primera página
print("Preview contenido:", docs[0].page_content[0:100])
print("Metadata:", docs[0].metadata)
# Out:
# Número de docs cargados: 4
# Preview contenido: Carga de datos
#
# Este proceso permite agregar en la liquidación de sueldos del trabajador, valores
# Metadata: {'producer': 'Microsoft® Word para Microsoft 365', 'creator': 'Microsoft® Word para Microsoft 365', 'creationdate': '2022-08-29T22:01:31-04:00', 'author': 'Juan Carlos Rojas Banda', 'moddate': '2022-08-29T22:01:31-04:00', 'source': 'carga.pdf', 'total_pages': 4, 'page': 0, 'page_label': '1'}

# %%
# 3. CONTAR TOKENS ANTES DE HACER NADA
# ----------------------------------------------------------------------------
tokens_en_documento = count_tokens_in_docs(docs, model_name="gpt-4o")
print("Tokens en el documento completo:", tokens_en_documento)
# Out:
# Tokens en el documento completo: 854

# %%
text_splitter = RecursiveCharacterTextSplitter(chunk_size=100, chunk_overlap=20)
splits = text_splitter.split_documents(docs)

# %%
# Crea los embeddings
embeddings = OpenAIEmbeddings()
vectorstore = FAISS.from_documents(splits, embeddings)

# Crea el retriever
retriever = vectorstore.as_retriever(search_kwargs={"k": 3})

# %%
# Modelo utilizado
llm = ChatOpenAI(model="gpt-4o")

# %%
# Creación del estado
class GlobalState(TypedDict): # Estado Globa
    graph: str
    messages: list[dict] # Es una lista de diccionarios
    next: str
    
class SearchState(TypedDict):
    search: List[dict]

# %%
# Miembros del equipo
members = ["researcher", "retriever", "amparo"]
options = members + ["FINISH"]

# %%
# Router con opciones para el llm
class Router(TypedDict):
    """Worker to route to next. If no workers needed, route to FINISH."""

    next: Literal["researcher", "retriever","amparo",  "FINISH"]

# %%
system_prompt = (
    "Tu nombre es Amparo, un asistente virtual que apoya las gestiones en el área de Recursos Humanos "
    "de la empresa Constructora del Mar II. Tu función principal es gestionar las solicitudes del usuario "
    f"derivándolas a los siguientes agentes especializados: {members}.\n\n"
    
    "El agente especializado 'researcher' se encarga de realizar búsquedas de información en la web.\n"
    "El agente especializado 'retriever' se encarga de recuperar información desde un documento llamado 'Carga de Datos'. "
    "Este documento contiene instrucciones sobre cómo cargar información en el módulo UnyRem del ERP Unysoft.\n\n"
    
    "Tu tarea es analizar la pregunta del usuario y decidir cuál agente debe actuar en función de la solicitud.\n"
    "Si la solicitud es general o informal, selecciona el agente más apropiado para responder o investigar.\n"
    "Solo responde 'FINISH' si el usuario está completamente satisfecho y no hay más tareas pendientes.\n\n"
    
    "Devuelve **únicamente** el nombre del trabajador a activar (por ejemplo: retriever), o 'FINISH' si todo ha concluido."
)


print(system_prompt)
# Out:
# Tu nombre es Amparo, un asistente virtual que apoya las gestiones en el área de Recursos Humanos de la empresa Constructora del Mar II. Tu función principal es gestionar las solicitudes del usuario derivándolas a los siguientes agentes especializados: ['researcher', 'retriever', 'amparo'].
#
# El agente especializado 'researcher' se encarga de realizar búsquedas de información en la web.
# El agente especializado 'retriever' se encarga de recuperar información desde un documento llamado 'Carga de Datos'. Este documento contiene instrucciones sobre cómo cargar información en el módulo UnyRem del ERP Unysoft.
#
# Tu tarea es analizar la pregunta del usuario y decidir cuál agente debe actuar en función de la solicitud.
# Si la solicitud es general o informal, selecciona el agente más apropiado para responder o investigar.
# Solo responde 'FINISH' si el usuario está completamente satisfecho y no hay más tareas pendientes.
#
# Devuelve **únicamente** el nombre del trabajador a activar (por ejemplo: retriever), o 'FINISH' si todo ha concluido.

# %%
"""class IntentClassification(TypedDict):
    intent: Literal["info", "task"]

def classify_intent(user_input: str) -> str:
    classification_prompt = [
        {"role": "system", "content": (
            "Eres un clasificador de intención. Tu tarea es leer el mensaje del usuario y determinar si se trata de:\n"
            "- una pregunta de tipo personal o conversacional (por ejemplo: quién eres, cuál es tu rol), en cuyo caso responde 'info'.\n"
            "- una solicitud que requiere la ayuda de un agente para buscar información, en cuyo caso responde 'task'.\n\n"
            "Responde solo con 'info' o 'task'."
        )},
        {"role": "user", "content": user_input}
    ]

    result = llm.with_structured_output(IntentClassification).invoke(classification_prompt)
    return result["intent"]"""
# Out:
# 'class IntentClassification(TypedDict):\n    intent: Literal["info", "task"]\n\ndef classify_intent(user_input: str) -> str:\n    classification_prompt = [\n        {"role": "system", "content": (\n            "Eres un clasificador de intención. Tu tarea es leer el mensaje del usuario y determinar si se trata de:\n"\n            "- una pregunta de tipo personal o conversacional (por ejemplo: quién eres, cuál es tu rol), en cuyo caso responde \'info\'.\n"\n            "- una solicitud que requiere la ayuda de un agente para buscar información, en cuyo caso responde \'task\'.\n\n"\n            "Responde solo con \'info\' o \'task\'."\n        )},\n        {"role": "user", "content": user_input}\n    ]\n\n    result = llm.with_structured_output(IntentClassification).invoke(classification_prompt)\n    return result["intent"]'

# %%
# Definir un nodo info o agent principal
system_prompt_amparo = "Eres Amparo un asistente virtual creado para apoyar al depto de rrhh de la empresa consstructora del mar. Tu trabajo consiste en responder a las solicitudes de los usuarios"
"""
Este nodo permitirá que el usuario interactue de una manera más natural con el sistema multiagente
"""

info_agent = create_react_agent(
    llm,
    tools=[],
    prompt=ChatPromptTemplate.from_messages([
        ("system", system_prompt_amparo),
        ("human", "{messages}")
    ])
)

def amparo(state: GlobalState) -> Command[Literal["feedback"]]:
    result = info_agent.invoke(state)
    return Command(
        goto="feedback",
        update={"messages": result["messages"]}
    )

# %%
def supervisor_node(state: GlobalState) -> Command[Literal["researcher", "retriever","amparo"]]:
    """user_input = state["messages"][-1]["content"]
    intent = classify_intent(user_input)    
    print("intent: ", intent)
    if intent[0] == "info":
        print("INTENT DEBUG tipo de mensaje:", type(state["messages"][-1]))
        # response = llm.with_structured_output(intent).invoke(state)
        goto = "amparo"
    else:
        print(" SUPERVISOR DEBUG tipo de mensaje:", type(state["messages"][-1]))
        print(state["messages"])"""
    messages = [{"role":"system", "content":system_prompt},] + state["messages"]
    response = llm.with_structured_output(Router).invoke(messages)
    goto = response["next"]
    print("DIRIGIENDO FLUJO A: ", goto)
    """if goto == "FINISH":
        goto = END"""
    
    return Command(goto=goto, update = {"next":goto})

# %%
from langchain_core.messages import HumanMessage

def feedback_node(state: GlobalState) -> Command[Literal["supervisor", "__end__"]]:
    last_message = state["messages"][-1]
    print("LAST MESSAGE: ", last_message)
    if isinstance(last_message, HumanMessage):
        user_message = last_message.content.lower()
        print("USER MESSAGE: ", user_message)

        if any(x in user_message for x in ["gracias", "ok", "sí", "perfecto", "entendido", "me quedó claro"]):
            print("✅ Feedback positivo. Cerrando flujo.")
            return Command(goto=END, update={})
    
    print("🔁 Feedback negativo o nueva pregunta. Reiniciando supervisor.")
    return Command(goto="supervisor", update={})

# %%
# Tool de search node 
tavily_tool = TavilySearchResults(max_results=1)
research_agent = create_react_agent(
    llm, tools=[tavily_tool], prompt="Eres un agente especializado en busqueda web."
)

# %%
def search_node(state: GlobalState) -> Command[Literal["feedback"]]:
    result = research_agent.invoke(state)
    # print("DEBUG result: ", result)  # <-- esto

    return Command(goto="feedback", 
                   update = {
                       "__state__": {"search":result["messages"]},"messages":result["messages"]})

# %%
# Crea una herramienta a partir del retriever
retriever_tool = create_retriever_tool(
    retriever,
    name="reglamento_retriever",
    description="Busca información manual de Unyrem de Unysoft."
)

# %%
# Crea el agente con la herramienta
retriever_agent = create_react_agent(
    llm,
    tools=[retriever_tool],
    prompt="Eres un agente experto en responder preguntas sobre el manual de carga de datos al módulo UnyRem del sistema Unysoft,"
)

# %%
def retriever_node(state: GlobalState) -> Command[Literal["feedback"]]:
    result = retriever_agent.invoke(state)
    return Command(
        goto="feedback",
        update={
            "messages": result["messages"]
        }
    )

# %%
builder = StateGraph(GlobalState)
builder.add_edge(START, "supervisor")
builder.add_node("feedback", feedback_node)
builder.add_node("amparo", amparo)
builder.add_node("supervisor", supervisor_node)
builder.add_node("researcher",search_node)
builder.add_node("retriever",retriever_node)

graph =  builder.compile()
display(Image(graph.get_graph().draw_mermaid_png()))

# %%
from langchain_core.messages import HumanMessage

# Paso 1: pregunta inicial
sal = graph.invoke({"messages": [HumanMessage(content="¿Quién eres?")]})
for m in sal["messages"]:
    m.pretty_print()
# Out:
# DIRIGIENDO FLUJO A:  amparo
# LAST MESSAGE:  content='Hola, soy Amparo, el asistente virtual del departamento de recursos humanos de la empresa Constructora del Mar. Estoy aquí para ayudarte con cualquier consulta o solicitud relacionada con nuestras políticas de recursos humanos, procesos de selección, beneficios laborales, entre otros. ¿En qué puedo asistirte hoy?' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 59, 'prompt_tokens': 90, 'total_tokens': 149, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_6bb567654c', 'id': 'chatcmpl-BFOUBqRe9mvc1JnRHkcgmzawMbUwU', 'finish_reason': 'stop', 'logprobs': None} id='run-157b7f26-cf9c-4b5e-9f42-da0f2339f541-0' usage_metadata={'input_tokens': 90, 'output_tokens': 59, 'total_tokens': 149, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
# 🔁 Feedback negativo o nueva pregunta. Reiniciando supervisor.
# DIRIGIENDO FLUJO A:  amparo
# LAST MESSAGE:  content='Hola de nuevo, soy Amparo, tu asistente virtual para el departamento de recursos humanos. Estoy aquí para ayudarte con cualquier consulta relacionada con recursos humanos, como políticas de la empresa, procesos de contratación, gestión de beneficios y más. ¿En qué necesitas ayuda hoy?' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 55, 'prompt_tokens': 406, 'total_tokens': 461, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_6bb567654c', 'id': 'chatcmpl-BFOUDdCRQgaZ2t18BOnJ53bp8AhIU', 'finish_reason': 'stop', 'logprobs': None} id='run-fa88e969-4785-4777-bd6f-ee4699225f35-0' usage_metadata={'input_tokens': 406, 'output_tokens': 55, 'total_tokens': 461, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
# 🔁 Feedback negativo o nueva pregunta. Reiniciando supervisor.
# DIRIGIENDO FLUJO A:  amparo
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4288\4113677519.py in <module>
#       2
#       3 # Paso 1: pregunta inicial
# ----> 4 sal = graph.invoke({"messages": [HumanMessage(content="¿Quién eres?")]})
#       5 for m in sal["messages"]:
#       6     m.pretty_print()
#
# ~\anaconda3\lib\site-packages\langgraph\pregel\__init__.py in invoke(self, input, config, stream_mode, output_keys, interrupt_before, interrupt_after, debug, **kwargs)
#    2681         else:
#    2682             chunks = []
# -> 2683         for chunk in self.stream(
#    2684             input,
#    2685             config,
#
# ~\anaconda3\lib\site-packages\langgraph\pregel\__init__.py in stream(self, input, config, stream_mode, output_keys, interrupt_before, interrupt_after, debug, subgraphs)
#    2329                 # with channel updates applied only at the transition between steps.
#    2330                 while loop.tick(input_keys=self.input_channels):
# -> 2331                     for _ in runner.tick(
#    2332                         loop.tasks.values(),
#    2333                         timeout=self.step_timeout,
#
# ~\anaconda3\lib\site-packages\langgraph\pregel\runner.py in tick(self, tasks, reraise, timeout, retry_policy, get_waiter)
#     144             t = tasks[0]
#     145             try:
# --> 146                 run_with_retry(
#     147                     t,
#     148                     retry_policy,
#
# ~\anaconda3\lib\site-packages\langgraph\pregel\retry.py in run_with_retry(task, retry_policy, configurable)
#      38             task.writes.clear()
#      39             # run the task
# ---> 40             return task.proc.invoke(task.input, config)
#      41         except ParentCommand as exc:
#      42             ns: str = config[CONF][CONFIG_KEY_CHECKPOINT_NS]
#
# ~\anaconda3\lib\site-packages\langgraph\utils\runnable.py in invoke(self, input, config, **kwargs)
#     604                 )
#     605                 if i == 0:
# --> 606                     input = step.invoke(input, config, **kwargs)
#     607                 else:
#     608                     input = step.invoke(input, config)
#
# ~\anaconda3\lib\site-packages\langgraph\utils\runnable.py in invoke(self, input, config, **kwargs)
#     369         else:
#     370             with set_config_context(config) as context:
# --> 371                 ret = context.run(self.func, *args, **kwargs)
#     372         if isinstance(ret, Runnable) and self.recurse:
#     373             return ret.invoke(input, config)
#
# ~\AppData\Local\Temp\ipykernel_4288\530492349.py in amparo(state)
#      15
#      16 def amparo(state: GlobalState) -> Command[Literal["feedback"]]:
# ---> 17     result = info_agent.invoke(state)
#      18     return Command(
#      19         goto="feedback",
#
# ~\anaconda3\lib\site-packages\langgraph\pregel\__init__.py in invoke(self, input, config, stream_mode, output_keys, interrupt_before, interrupt_after, debug, **kwargs)
#    2681         else:
#    2682             chunks = []
# -> 2683         for chunk in self.stream(
#    2684             input,
#    2685             config,
#
# ~\anaconda3\lib\site-packages\langgraph\pregel\__init__.py in stream(self, input, config, stream_mode, output_keys, interrupt_before, interrupt_after, debug, subgraphs)
#    2329                 # with channel updates applied only at the transition between steps.
#    2330                 while loop.tick(input_keys=self.input_channels):
# -> 2331                     for _ in runner.tick(
#    2332                         loop.tasks.values(),
#    2333                         timeout=self.step_timeout,
#
# ~\anaconda3\lib\site-packages\langgraph\pregel\runner.py in tick(self, tasks, reraise, timeout, retry_policy, get_waiter)
#     144             t = tasks[0]
#     145             try:
# --> 146                 run_with_retry(
#     147                     t,
#     148                     retry_policy,
#
# ~\anaconda3\lib\site-packages\langgraph\pregel\retry.py in run_with_retry(task, retry_policy, configurable)
#      38             task.writes.clear()
#      39             # run the task
# ---> 40             return task.proc.invoke(task.input, config)
#      41         except ParentCommand as exc:
#      42             ns: str = config[CONF][CONFIG_KEY_CHECKPOINT_NS]
#
# ~\anaconda3\lib\site-packages\langgraph\utils\runnable.py in invoke(self, input, config, **kwargs)
#     604                 )
#     605                 if i == 0:
# --> 606                     input = step.invoke(input, config, **kwargs)
#     607                 else:
#     608                     input = step.invoke(input, config)
#
# ~\anaconda3\lib\site-packages\langgraph\utils\runnable.py in invoke(self, input, config, **kwargs)
#     361                 child_config = patch_config(config, callbacks=run_manager.get_child())
#     362                 with set_config_context(child_config) as context:
# --> 363                     ret = context.run(self.func, *args, **kwargs)
#     364             except BaseException as e:
#     365                 run_manager.on_chain_error(e)
#
# ~\anaconda3\lib\site-packages\langgraph\prebuilt\chat_agent_executor.py in call_model(state, config)
#     684         messages = _get_state_value(state, "messages")
#     685         _validate_chat_history(messages)
# --> 686         response = cast(AIMessage, model_runnable.invoke(state, config))
#     687         # add agent name to the AIMessage
#     688         response.name = name
#
# ~\anaconda3\lib\site-packages\langchain_core\runnables\base.py in invoke(self, input, config, **kwargs)
#    3023                         input = context.run(step.invoke, input, config, **kwargs)
#    3024                     else:
# -> 3025                         input = context.run(step.invoke, input, config)
#    3026         # finish the root run
#    3027         except BaseException as e:
#
# ~\anaconda3\lib\site-packages\langchain_core\language_models\chat_models.py in invoke(self, input, config, stop, **kwargs)
#     305         return cast(
#     306             ChatGeneration,
# --> 307             self.generate_prompt(
#     308                 [self._convert_input(input)],
#     309                 stop=stop,
#
# ~\anaconda3\lib\site-packages\langchain_core\language_models\chat_models.py in generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     841     ) -> LLMResult:
#     842         prompt_messages = [p.to_messages() for p in prompts]
# --> 843         return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#     844
#     845     async def agenerate_prompt(
#
# ~\anaconda3\lib\site-packages\langchain_core\language_models\chat_models.py in generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     681             try:
#     682                 results.append(
# --> 683                     self._generate_with_cache(
#     684                         m,
#     685                         stop=stop,
#
# ~\anaconda3\lib\site-packages\langchain_core\language_models\chat_models.py in _generate_with_cache(self, messages, stop, run_manager, **kwargs)
#     906         else:
#     907             if inspect.signature(self._generate).parameters.get("run_manager"):
# --> 908                 result = self._generate(
#     909                     messages, stop=stop, run_manager=run_manager, **kwargs
#     910                 )
#
# ~\anaconda3\lib\site-packages\langchain_openai\chat_models\base.py in _generate(self, messages, stop, run_manager, **kwargs)
#     923             generation_info = {"headers": dict(raw_response.headers)}
#     924         else:
# --> 925             response = self.client.create(**payload)
#     926         return self._create_chat_result(response, generation_info)
#     927
#
# ~\anaconda3\lib\site-packages\openai\_utils\_utils.py in wrapper(*args, **kwargs)
#     277                         msg = f"Missing required argument: {quote(missing[0])}"
#     278                 raise TypeError(msg)
# --> 279             return func(*args, **kwargs)
#     280
#     281         return wrapper  # type: ignore
#
# ~\anaconda3\lib\site-packages\openai\resources\chat\completions\completions.py in create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, reasoning_effort, response_format, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, web_search_options, extra_headers, extra_query, extra_body, timeout)
#     912     ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     913         validate_response_format(response_format)
# --> 914         return self._post(
#     915             "/chat/completions",
#     916             body=maybe_transform(
#
# ~\anaconda3\lib\site-packages\openai\_base_client.py in post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1240             method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1241         )
# -> 1242         return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#    1243
#    1244     def patch(
#
# ~\anaconda3\lib\site-packages\openai\_base_client.py in request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     917             retries_taken = 0
#     918
# --> 919         return self._request(
#     920             cast_to=cast_to,
#     921             options=options,
#
# ~\anaconda3\lib\site-packages\openai\_base_client.py in _request(self, cast_to, options, retries_taken, stream, stream_cls)
#     953
#     954         try:
# --> 955             response = self._client.send(
#     956                 request,
#     957                 stream=stream or self._should_stream_response_body(request=request),
#
# ~\anaconda3\lib\site-packages\httpx\_client.py in send(self, request, stream, auth, follow_redirects)
#     912         auth = self._build_request_auth(request, auth)
#     913
# --> 914         response = self._send_handling_auth(
#     915             request,
#     916             auth=auth,
#
# ~\anaconda3\lib\site-packages\httpx\_client.py in _send_handling_auth(self, request, auth, follow_redirects, history)
#     940
#     941             while True:
# --> 942                 response = self._send_handling_redirects(
#     943                     request,
#     944                     follow_redirects=follow_redirects,
#
# ~\anaconda3\lib\site-packages\httpx\_client.py in _send_handling_redirects(self, request, follow_redirects, history)
#     977                 hook(request)
#     978
# --> 979             response = self._send_single_request(request)
#     980             try:
#     981                 for hook in self._event_hooks["response"]:
#
# ~\anaconda3\lib\site-packages\httpx\_client.py in _send_single_request(self, request)
#    1012
#    1013         with request_context(request=request):
# -> 1014             response = transport.handle_request(request)
#    1015
#    1016         assert isinstance(response.stream, SyncByteStream)
#
# ~\anaconda3\lib\site-packages\httpx\_transports\default.py in handle_request(self, request)
#     248         )
#     249         with map_httpcore_exceptions():
# --> 250             resp = self._pool.handle_request(req)
#     251
#     252         assert isinstance(resp.stream, typing.Iterable)
#
# ~\anaconda3\lib\site-packages\httpcore\_sync\connection_pool.py in handle_request(self, request)
#     254
#     255             self._close_connections(closing)
# --> 256             raise exc from None
#     257
#     258         # Return the response. Note that in this case we still have to manage
#
# ~\anaconda3\lib\site-packages\httpcore\_sync\connection_pool.py in handle_request(self, request)
#     234                 try:
#     235                     # Send the request on the assigned connection.
# --> 236                     response = connection.handle_request(
#     237                         pool_request.request
#     238                     )
#
# ~\anaconda3\lib\site-packages\httpcore\_sync\connection.py in handle_request(self, request)
#     101             raise exc
#     102
# --> 103         return self._connection.handle_request(request)
#     104
#     105     def _connect(self, request: Request) -> NetworkStream:
#
# ~\anaconda3\lib\site-packages\httpcore\_sync\http11.py in handle_request(self, request)
#     134                 with Trace("response_closed", logger, request) as trace:
#     135                     self._response_closed()
# --> 136             raise exc
#     137
#     138     # Sending the request...
#
# ~\anaconda3\lib\site-packages\httpcore\_sync\http11.py in handle_request(self, request)
#     104                     headers,
#     105                     trailing_data,
# --> 106                 ) = self._receive_response_headers(**kwargs)
#     107                 trace.return_value = (
#     108                     http_version,
#
# ~\anaconda3\lib\site-packages\httpcore\_sync\http11.py in _receive_response_headers(self, request)
#     175
#     176         while True:
# --> 177             event = self._receive_event(timeout=timeout)
#     178             if isinstance(event, h11.Response):
#     179                 break
#
# ~\anaconda3\lib\site-packages\httpcore\_sync\http11.py in _receive_event(self, timeout)
#     215
#     216             if event is h11.NEED_DATA:
# --> 217                 data = self._network_stream.read(
#     218                     self.READ_NUM_BYTES, timeout=timeout
#     219                 )
#
# ~\anaconda3\lib\site-packages\httpcore\_backends\sync.py in read(self, max_bytes, timeout)
#     126         with map_exceptions(exc_map):
#     127             self._sock.settimeout(timeout)
# --> 128             return self._sock.recv(max_bytes)
#     129
#     130     def write(self, buffer: bytes, timeout: float | None = None) -> None:
#
# ~\anaconda3\lib\ssl.py in recv(self, buflen, flags)
#    1225                     "non-zero flags not allowed in calls to recv() on %s" %
#    1226                     self.__class__)
# -> 1227             return self.read(buflen)
#    1228         else:
#    1229             return super().recv(buflen, flags)
#
# ~\anaconda3\lib\ssl.py in read(self, len, buffer)
#    1100                 return self._sslobj.read(len, buffer)
#    1101             else:
# -> 1102                 return self._sslobj.read(len)
#    1103         except SSLError as x:
#    1104             if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:
